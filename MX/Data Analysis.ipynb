# 24  Health and fitness enthusiast (people have fit...
#
#                             Q5  \
# 0   I don't use any smartwatch
# 1   I don't use any smartwatch
# 2                        Apple
# 3                        Apple
# 4                       Fitbit
# 5                        Apple
# 6                       Fitbit
# 7                        Apple
# 8                       Fitbit
# 9                       Huawei
# 10                       Other
# 11                     Samsung
# 12                       Apple
# 13                       Apple
# 14                       Apple
# 15                      Fitbit
# 16                       Apple
# 17                      Fitbit
# 18                       Apple
# 19                       Other
# 20                       Other
# 21  I don't use any smartwatch
# 22                      Fitbit
# 23                       Apple
# 24                     Samsung
#
#                                                    Q6  \
# 0   Battery;Apps/Software Interface;Compatibility ...
# 1   Nothing, I love my smartwatch/Don't have a sma...
# 2                    Compatibility with other devices
# 3   Nothing, I love my smartwatch/Don't have a sma...
# 4   Screen (eg: brightness, easily scratched);Apps...
# 5                             Apps/Software Interface
# 6   Strap (eg: uncomfortable, smells bad after wor...
# 7                                             Battery
# 8           Screen (eg: brightness, easily scratched)
# 9   Dial;Apps/Software Interface;Nothing, I love m...
# 10  Nothing, I love my smartwatch/Don't have a sma...
# 11  Battery;Screen (eg: brightness, easily scratch...
# 12  Apps/Software Interface;Compatibility with oth...
# 13           Battery;Compatibility with other devices
# 14  Battery;Screen (eg: brightness, easily scratch...
# 15  Strap (eg: uncomfortable, smells bad after wor...
# 16  Nothing, I love my smartwatch/Don't have a sma...
# 17  Strap (eg: uncomfortable, smells bad after wor...
# 18                                            Battery
# 19  Strap (eg: uncomfortable, smells bad after wor...
# 20                                            Battery
# 21  Strap (eg: uncomfortable, smells bad after wor...
# 22  Strap (eg: uncomfortable, smells bad after wor...
# 23  Battery;Screen (eg: brightness, easily scratched)
# 24  Battery;Screen (eg: brightness, easily scratched)
#
#                                                    Q7  \
# 0                                                 NaN
# 1                                                 NaN
# 2               Can use with device other than iPhone
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   My strap broke - I had to borrow the straps of...
# 7                                 longer battery life
# 8                                                 NaN
# 9   Easy access to some features, finding little d...
# 10                                                NaN
# 11  longer battery life, mine doesn't even last me...
# 12  I would like my device to track my workouts ef...
# 13  Better integration, more relevant suggestions ...
# 14  Longer battery life. The screen is pretty good...
# 15                                                NaN
# 16                                                NaN
# 17  More customizability of what is displayed an t...
# 18  Longer battery life so I could actually use th...
# 19                                                NaN
# 20            Accuracy and usefulness of measurements
# 21                                                NaN
# 22  I wish I didn't have to take it off for a long...
# 23                                                NaN
# 24                                                NaN
#
#                                                    Q8  \
# 0   Calorie tracking;Solar chargeable battery (You...
# 1   Solar chargeable battery (Your battery charges...
# 2                    Calorie tracking;Water resistant
# 3   Solar chargeable battery (Your battery charges...
# 4   Solar chargeable battery (Your battery charges...
# 5   Synchronised workouts with friends on watch;GP...
# 6   Customisable strap;Solar chargeable battery (Y...
# 7   Solar chargeable battery (Your battery charges...
# 8   Calorie tracking;Customisable strap;Synchronis...
# 9   Customisable strap;Solar chargeable battery (Y...
# 10  Calorie tracking;Customisable strap;Solar char...
# 11  Customisable strap;Solar chargeable battery (Y...
# 12  Synchronised workouts with friends on watch;Po...
# 13  Virtual fitness trainer on watch that designs ...
# 14  Calorie tracking;Customisable strap;GPS tracke...
# 15  Calorie tracking;Solar chargeable battery (You...
# 16  Feature to set, track and remind of fitness go...
# 17  Solar chargeable battery (Your battery charges...
# 18                                              Other
# 19  Customisable strap;Solar chargeable battery (Y...
# 20  Solar chargeable battery (Your battery charges...
# 21  Calorie tracking;Customisable strap;GPS tracke...
# 22  Calorie tracking;Solar chargeable battery (You...
# 23  Calorie tracking;GPS tracker (eg: for tracking...
# 24  Calorie tracking;Solar chargeable battery (You...
#
#                                                    Q9
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   I would like to be able to do other things on ...
# 5                                                 NaN
# 6                                                   -
# 7                                                 NaN
# 8                                                nope
# 9                        I like the Sleep Tracker too
# 10                                           I didn't
# 11                                                NaN
# 12  I would like a workout timer which will be dis...
# 13                                                NaN
# 14  Additional sensors, like blood pressure or glu...
# 15                                               None
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Better interface for recharging, the strap suc...
# 20                  HRV, recovery, and sleep tracking
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %% [markdown]
# ![](images/1.png)

# %%
sns.countplot(y="Q1", data=df)

# %% [markdown]
# ![](images/2.png)

# %%
sns.countplot(y="Q2", data=df)

# %% [markdown]
# ![](images/3.png)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q3"].to_list()]:
    for element in list_:
        new_list.append(element)
    
sns.countplot(y=new_list)

# %% [markdown]
# ![](images/4.png)

# %%
sns.catplot(y="Q4", kind="count", data=df)

# %% [markdown]
# ![](images/5.png)

# %%
sns.catplot(y="Q5", kind="count", data=df)

# %% [markdown]
# ![](images/6.png)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q6"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %% [markdown]
# ![](images/7.png)

# %%
df["Q7"].dropna().to_list()
# Out:
# ['Can use with device other than iPhone',
#  "My strap broke - I had to borrow the straps of my mom's fitbit(she doesn't wear them). Now I have pink straps to a black watch.",
#  'longer battery life',
#  'Easy access to some features, finding little difficult to access the desired application',
#  "longer battery life, mine doesn't even last me more than 12 hours. Brightness is an issue especially when I am out running.",
#  "I would like my device to track my workouts efficiently. Even though I have selected the right setting of workout detections, there are times it won't detect the workout and at times it will not turn of the workout and count extra.",
#  'Better integration, more relevant suggestions with data collected',
#  "Longer battery life. The screen is pretty good, but it sometimes doesn't turn the backlight on all the way and could use a little more scratch resistance. I'm not sure what's wrong with the software, but I tend not to do much on the watch itself, because there's not much room to do anything. Siri shouldn't fail. It's not always clear what a vibration was for. I'd like the device to be a little slimmer and wrap the screen around my wrist. History of noise levels, though ignoring noise from a sleeve could be tough.",
#  'More customizability of what is displayed an the order, the app interface should have more extensive abilities to do those things',
#  'Longer battery life so I could actually use the sleep tracking features of my Apple Watch. ',
#  'Accuracy and usefulness of measurements',
#  "I wish I didn't have to take it off for a long period of time to charge. What if I want to use it?"]

# %% [markdown]
# ![](images/8.png)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q8"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %% [markdown]
# ![](images/9.png)

# %%
df["Q9"].dropna().to_list()
# Out:
# ["I would like to be able to do other things on my fitbit while I'm tracking my workout",
#  '-',
#  'nope',
#  'I like the Sleep Tracker too',
#  "I didn't",
#  'I would like a workout timer which will be displayed live on the screen instead of running in the background.',
#  'Additional sensors, like blood pressure or glucose.',
#  'None',
#  'Better interface for recharging, the strap sucks for sleeping with it',
#  'HRV, recovery, and sleep tracking']
